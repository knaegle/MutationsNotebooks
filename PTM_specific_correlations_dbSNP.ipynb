# %% [markdown]
# # Is there study bias on proteins with pathogenic mutations?
# Like with the other study bias code, we perform the same analysis her, except examining each induvidual modification separately.

# %%
# Setup the workspace, 
from proteomeScoutAPI import ProteomeScoutAPI
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from pylab import *
import pandas as pd
from scipy import stats 
import pickle

# set this to 0 if you would like to perform analysis on the entire set, 1 means we will remove extreme 
# outlier proteins in terms of lenght, GO annotations, mutations, or PTMS
FILTER = 1 
# %matplotlib inline

# define input file for ProteomeScout data
proteomeScoutFile = '/Users/alex/Dropbox/WASHU/naegle/mutants_paper/data/v1.0a_July_2015/proteomescout_everything_20150712.tsv'

# read in ProteomeScout data
PTM_API = ProteomeScoutAPI(proteomeScoutFile)

# get all human protein IDs
uniKeys = PTM_API.uniqueKeys
humanIds = []
for key in uniKeys:
    species = PTM_API.get_species(key)
    if species == 'homo sapiens':
        humanIds.append(key)

# %%
print "The number of proteins being examined is: %i" % (len(humanIds))
# Out:
# The number of proteins being examined is: 21968

# %%
# for every protein get the sequence, GO terms, PTMs and mutations
protDict = {}
for ID in humanIds:
    
    # for each protein ID extract the sequence, GO terms
    # PTMs, and any mutations from the SwissProtsmMuts dataset
    tempProtDict = {}
    tempProtDict['sequence'] = PTM_API.get_sequence(ID)
    tempProtDict['GO_terms'] = PTM_API.get_GO(ID)
    
    # if we find mutations set them, else set an empty
    # list
    tempProtDict['mutations'] = PTM_API.get_mutations(ID)
    tempProtDict['PTMs'] = PTM_API.get_PTMs(ID)
    
    if not isinstance(tempProtDict['mutations'] , (int, long)):
        protDict[ID] = tempProtDict
    else:
        print "Error, not adding ID:%s to dictionary since there was a problem"%(ID)
# Out:
# Error: Not the same number of annotations (43) and mutations (27)
#
# Error, not adding ID:49255 to dictionary since there was a problem
# Error: Not the same number of annotations (7) and mutations (5)
#
# Error, not adding ID:49574 to dictionary since there was a problem
# Error: Not the same number of annotations (9) and mutations (7)
#
# Error, not adding ID:53705 to dictionary since there was a problem
# Error: Not the same number of annotations (13) and mutations (11)
#
# Error, not adding ID:53797 to dictionary since there was a problem
# Error: Not the same number of annotations (14) and mutations (12)
#
# Error, not adding ID:53906 to dictionary since there was a problem
# Error: Not the same number of annotations (10) and mutations (6)
#
# Error, not adding ID:114257 to dictionary since there was a problem
# Error: Not the same number of annotations (9) and mutations (7)
#
# Error, not adding ID:114267 to dictionary since there was a problem
# Error: Not the same number of annotations (11) and mutations (9)
#
# Error, not adding ID:114360 to dictionary since there was a problem
# Error: Not the same number of annotations (19) and mutations (17)
#
# Error, not adding ID:125153 to dictionary since there was a problem
# Error: Not the same number of annotations (284) and mutations (166)
#
# Error, not adding ID:125174 to dictionary since there was a problem
# Error: Not the same number of annotations (76) and mutations (56)
#
# Error, not adding ID:125182 to dictionary since there was a problem
# Error: Not the same number of annotations (8) and mutations (3)
#
# Error, not adding ID:155029 to dictionary since there was a problem
# Error: Not the same number of annotations (8) and mutations (6)
#
# Error, not adding ID:203402 to dictionary since there was a problem

# %% [markdown]
# ### Creating a PTM specific dataframe
# Having extracted all the raw data, we now iterate over each protein and extract out protein-specific results, including the number of each specific type of mutation (phosphoserine, phosphothreonine, phosphotyrosine, ubiquitin, and N6-acetyllysine).

# %%
# create matched vectors of our items of interest
num_GO = []
num_muts = []
num_PS = []
num_PT = []
num_PY = []
num_UB = []
num_NK = []
num_PTMs = []
seqLength = []
pathoStatus = []
protIds = []

# for each ID in the protein dictionary
for ID in protDict:
    val = 0
    
    # check if any of the mutations in this protein are associated with a disease
    # according to the SwissProt disease mutation annotation
    # check if that mutation is associated with the word pathogenic
    try: 
        for m in protDict[ID]['mutations']:
            if m[3] == 'Pathogenic' or m[3]=='pathogenic':
                val = 1
    except Exception, e:
        print "Error with accessing ID %s"%(ID)

    # set the pathogenic states
    pathoStatus.append(val)
    
    ## increment the various lists with the number of 
    # GO terms
    num_GO.append(len(protDict[ID]['GO_terms']))
    
    # Mutations
    num_muts.append(len(protDict[ID]['mutations']))
    
    # All PTMs...
    num_PTMs.append(len(protDict[ID]['PTMs']))
    
    # >>>>>>>>>>>>>
    # initialize empty list
    # tempList[0] ==> Phosphoserine
    # tempList[1] ==> Phosphothereonine
    # tempList[2] ==> Phosphotyrosine
    # tempList[3] ==> Ubiquitination 
    # tempList[4] ==> N6-acetyllysine 
    tempList = [0,0,0,0,0]
    
    # get the set of PTMs from the record
    PTMList = protDict[ID]['PTMs']
    
    # for each record incremenet the appropriate counter
    for PTM in PTMList:
        if PTM[2] == 'Phosphoserine':
            tempList[0] = tempList[0]+1
            
        if PTM[2] == 'Phosphothreonine':
            tempList[1] = tempList[1]+1
            
        if PTM[2] == 'Phosphotyrosine':
            tempList[2] = tempList[2]+1
            
        if PTM[2] == 'Ubiquitination':
            tempList[3] = tempList[3]+1
            
        if PTM[2] == 'N6-acetyllysine':
            tempList[4] = tempList[4]+1
            
            
    num_PS.append(tempList[0])
    num_PT.append(tempList[1])
    num_PY.append(tempList[2])
    num_UB.append(tempList[3])
    num_NK.append(tempList[4])

    
    # Sequence length
    seqLength.append(len(protDict[ID]['sequence']))
    protIds.append(ID)
    
# build a PANDAs dataframe
df = pd.DataFrame({'GO': num_GO,
                   'Mutations': num_muts,
                   'PTMs': num_PTMs,
                   'pSer': num_PS,
                   'pThr': num_PT,
                   'pTyr': num_PY,
                   'Ubiq': num_UB,
                   'N6AK': num_NK,
                   'Sequence': seqLength})

pathoS = pd.Series(pathoStatus)
protId_S = pd.Series(protIds)
df.describe()
# Out:
#                  GO     Mutations          N6AK          PTMs      Sequence  \
# count  21955.000000  21955.000000  21955.000000  21955.000000  21955.000000
# mean       7.893464      2.935550      0.970531     14.112093    624.852517
# std       11.023557     13.804495      2.540444     23.513187    635.596062
# min        0.000000      0.000000      0.000000      1.000000     10.000000
# 25%        0.000000      0.000000      0.000000      3.000000    296.000000
# 50%        4.000000      1.000000      0.000000      7.000000    469.000000
# 75%       11.000000      2.000000      1.000000     17.000000    750.000000
# max      159.000000   1338.000000     75.000000   1210.000000  34350.000000
#
#                Ubiq          pSer          pThr          pTyr
# count  21955.000000  21955.000000  21955.000000  21955.000000
# mean       1.644455      6.189251      2.617718      1.781644
# std        4.115999     11.709316      4.809747      3.512554
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000      0.000000
# 50%        0.000000      3.000000      1.000000      1.000000
# 75%        2.000000      7.000000      3.000000      2.000000
# max      205.000000    547.000000    267.000000    294.000000

# %% [markdown]
# We can summarize the information for each protein by printing the dataframe, as shown below;

# %%
df
df['Mutations'].sum()
# Out:
# 64450

# %% [markdown]
# ## Plotting 6-panel figures
# Having generated a summary record for each protein, we can now go and subselect the sample of proteins which have 1 or more modification of each type, and then ask how that subsample's properties are correlated with one another. For example, in proteins with one or more phosphotyrosine modification perhaps number of pTyr sites and GO are well correlated? Who knows - let's find out!

# %%
# set various initial parameters (can be modificed to change figure appearance)
nrows = 2
ncols = 3
SCATTER_SIZE=40
LABEL_SIZE = 8
ALPHA=0.2
BORDER_WIDTH=0.2
SHOW_LEGEND = False

# explicitly set tick labels to overide matplotlib's default spacing
TICKS = {'Mutations':np.arange(0,450,100), 'GO':np.arange(0,250,50), 'PTMs':np.arange(0,450,100),'Sequence':np.arange(0,12500,2500)}

# keep the same limits as used in the main text figure
LIMITS = {'GO':200, 'Mutations':400, 'PTMs':420,'Sequence':10000}
KEYS = ['Mutations', 'Sequence','GO']

PTM_TYPES = ['pSer', 'pThr','pTyr','Ubiq','N6AK']
KEY_PAIRS = [['Mutations','PTMs'],['PTMs','Sequence'],['Mutations','Sequence'],['GO','Mutations'],['GO','PTMs'],['GO','Sequence']]                                                        

# loop generates a 6 pannel subplot per modifictaion type
for PTM_TYPE in PTM_TYPES:
    
    # extract a subset of proteins where there is at least one modfication of the type
    # of interest
    subset = df[df[PTM_TYPE] > 1]
    
    # initialize the multiplot figure row and column indices
    idxCol = 0
    idxRow = 0

    fig, axes = plt.subplots(nrows=nrows, ncols=ncols)
    fig.tight_layout(pad=0.4, w_pad=2, h_pad=1.0)

    for KEY_PAIR in KEY_PAIRS:

        # set keys
        key1 = KEY_PAIR[0]
        key2 = KEY_PAIR[1]
        
        # if we're looking at a PTM replace the 'PTMs' keyword with the 
        # specific PTM we're looking at!
        PTMMODE=False
        if key2 == 'PTMs':
            key2_selector = PTM_TYPE
        else:
            key2_selector = key2
            
        if key1 == 'PTMs':
            key1_selector = PTM_TYPE
        else:
            key1_selector = key1
    
                    
        # draw the scatter plot (all and pathogenic protein)    
        axes[idxRow, idxCol].scatter(subset[key1_selector], subset[key2_selector], alpha=ALPHA, lw = BORDER_WIDTH,s=SCATTER_SIZE)
        axes[idxRow, idxCol].scatter(subset[key1_selector][pathoS==1], subset[key2_selector][pathoS==1], c='r',alpha=ALPHA, lw = BORDER_WIDTH, s=SCATTER_SIZE)
        
        # set the plot object to the current axis for direct manipulation of plt variables
        plt.sca(axes[idxRow, idxCol])
    
        
        plt.xlim([0,LIMITS[key1]])
        plt.ylim([0,LIMITS[key2]])
    
        plt.xticks(TICKS[key1])
        plt.yticks(TICKS[key2])

        # change name for plots
        if key1 == 'Sequence':
            key1 = 'Protein length'
        if key2 == 'Sequence':
            key2 = 'Protein length'
    
        plt.xlabel(key1,size=LABEL_SIZE)
        plt.ylabel(key2,size=LABEL_SIZE)
        plt.tick_params(axis='x', labelsize=8)
        plt.tick_params(axis='y', labelsize=8)
        if SHOW_LEGEND:
            legend([L1,L2], LEGEND_TEXT,frameon=False,scatterpoints = 1)

        # update the row and column counter, resetting
        idxCol = idxCol + 1
        if idxCol % (ncols) == 0:
            idxCol = 0
            idxRow += 1

    savefig("figures/6_pannel_figure_%s.pdf"%(PTM_TYPE),bbox_inches='tight')

# %%
# create plots and calculate correlation
keys = df.columns
#pathoFilt = pathoStatus[indexes]
#%print len(pathoFilt)

if FILTER:
    dfFilt = df[(np.abs(stats.zscore(df)) < 20).all(axis=1)]
    indexes = df[(np.abs(stats.zscore(df)) < 20).all(axis=1)].index.tolist()
    pathoSFilt = pathoS[indexes]
    protIdsFilt = protId_S[indexes]
    df_path = dfFilt[:][pathoSFilt==1]
    df = dfFilt
    pathoS = pathoSFilt
    protId_S = protIdsFilt
    protId_pathoS = protId_S[pathoSFilt==1]
else:
    df_path = df[:][pathoS==1]  
    protId_pathoS = protId_S[pathoS==1]



df_path.describe()
df_path.sum()
# Out:
# GO            14730
# Mutations     20455
# N6AK           1425
# PTMs          16045
# Sequence     597323
# Ubiq           1709
# pSer           6017
# pThr           2747
# pTyr           2290
# dtype: int64

# %% [markdown]
# # Correlation across all data
# #### NOTE:
# With dbSNP mutations data, all the p-values for correlation were very low (p < $10^{-10}$) but with the SwissProt set of mutations now a number of the p-values are larger (notable PTMs vs. sequence and PTMs vs. GO).

# %%
rArr = []
pArr = []
keys = df.columns
PTM_TYPES = ['pSer', 'pThr','pTyr','Ubiq','N6AK']

for PTM_TYPE in PTM_TYPES:
    
    # extract a subset of proteins where there is at least one modfication of the type
    # of interest
    subset = df[df[PTM_TYPE] > 1]
    
    # initialize the multiplot figure!
    idxCol = 0
    idxRow = 0
    
    print "------------------------------------------------------------"
    print "     Correlation analysis for PTM type %s"%PTM_TYPE
    print "------------------------------------------------------------"
    s = ''
    for i in range(0, len(keys)):
        key1 = keys[i]
        for j in range(i+1, len(keys)):
            key2 = keys[j]
            [r, p] = stats.pearsonr(subset[key1], subset[key2])
            rArr.append(r)
            pArr.append(p)
            s = "%s%s and %s have correlation \t%0.2f with pvalue of %0.E\n"%(s, key1, key2, r, p)
    print s
    print "END OF SECTION"
    print ""
# Out:
# ------------------------------------------------------------
#      Correlation analysis for PTM type pSer
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.21 with pvalue of 7E-144
# GO and N6AK have correlation 	0.22 with pvalue of 5E-146
# GO and PTMs have correlation 	0.26 with pvalue of 9E-207
# GO and Sequence have correlation 	0.01 with pvalue of 2E-01
# GO and Ubiq have correlation 	0.29 with pvalue of 6E-259
# GO and pSer have correlation 	0.12 with pvalue of 5E-49
# GO and pThr have correlation 	0.17 with pvalue of 7E-95
# GO and pTyr have correlation 	0.26 with pvalue of 2E-207
# Mutations and N6AK have correlation 	0.09 with pvalue of 2E-24
# Mutations and PTMs have correlation 	0.11 with pvalue of 1E-41
# Mutations and Sequence have correlation 	0.19 with pvalue of 5E-118
# Mutations and Ubiq have correlation 	0.02 with pvalue of 3E-02
# Mutations and pSer have correlation 	0.08 with pvalue of 1E-20
# Mutations and pThr have correlation 	0.11 with pvalue of 5E-40
# Mutations and pTyr have correlation 	0.12 with pvalue of 6E-49
# N6AK and PTMs have correlation 	0.56 with pvalue of 0E+00
# N6AK and Sequence have correlation 	0.14 with pvalue of 6E-63
# N6AK and Ubiq have correlation 	0.46 with pvalue of 0E+00
# N6AK and pSer have correlation 	0.30 with pvalue of 5E-289
# N6AK and pThr have correlation 	0.38 with pvalue of 0E+00
# N6AK and pTyr have correlation 	0.34 with pvalue of 0E+00
# PTMs and Sequence have correlation 	0.44 with pvalue of 0E+00
# PTMs and Ubiq have correlation 	0.52 with pvalue of 0E+00
# PTMs and pSer have correlation 	0.88 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.84 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.65 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.08 with pvalue of 3E-21
# Sequence and pSer have correlation 	0.46 with pvalue of 0E+00
# Sequence and pThr have correlation 	0.47 with pvalue of 0E+00
# Sequence and pTyr have correlation 	0.34 with pvalue of 0E+00
# Ubiq and pSer have correlation 	0.22 with pvalue of 3E-147
# Ubiq and pThr have correlation 	0.30 with pvalue of 9E-291
# Ubiq and pTyr have correlation 	0.33 with pvalue of 0E+00
# pSer and pThr have correlation 	0.77 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.47 with pvalue of 0E+00
# pThr and pTyr have correlation 	0.49 with pvalue of 0E+00
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type pThr
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.21 with pvalue of 1E-98
# GO and N6AK have correlation 	0.21 with pvalue of 5E-100
# GO and PTMs have correlation 	0.24 with pvalue of 2E-130
# GO and Sequence have correlation 	-0.00 with pvalue of 9E-01
# GO and Ubiq have correlation 	0.29 with pvalue of 2E-186
# GO and pSer have correlation 	0.11 with pvalue of 2E-29
# GO and pThr have correlation 	0.14 with pvalue of 2E-42
# GO and pTyr have correlation 	0.24 with pvalue of 2E-132
# Mutations and N6AK have correlation 	0.08 with pvalue of 8E-16
# Mutations and PTMs have correlation 	0.10 with pvalue of 1E-24
# Mutations and Sequence have correlation 	0.20 with pvalue of 2E-92
# Mutations and Ubiq have correlation 	0.01 with pvalue of 4E-01
# Mutations and pSer have correlation 	0.07 with pvalue of 1E-12
# Mutations and pThr have correlation 	0.10 with pvalue of 1E-22
# Mutations and pTyr have correlation 	0.12 with pvalue of 5E-34
# N6AK and PTMs have correlation 	0.55 with pvalue of 0E+00
# N6AK and Sequence have correlation 	0.12 with pvalue of 9E-33
# N6AK and Ubiq have correlation 	0.47 with pvalue of 0E+00
# N6AK and pSer have correlation 	0.28 with pvalue of 1E-179
# N6AK and pThr have correlation 	0.35 with pvalue of 2E-279
# N6AK and pTyr have correlation 	0.32 with pvalue of 6E-235
# PTMs and Sequence have correlation 	0.42 with pvalue of 0E+00
# PTMs and Ubiq have correlation 	0.51 with pvalue of 0E+00
# PTMs and pSer have correlation 	0.89 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.82 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.64 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.06 with pvalue of 4E-09
# Sequence and pSer have correlation 	0.44 with pvalue of 0E+00
# Sequence and pThr have correlation 	0.44 with pvalue of 0E+00
# Sequence and pTyr have correlation 	0.32 with pvalue of 7E-234
# Ubiq and pSer have correlation 	0.20 with pvalue of 4E-87
# Ubiq and pThr have correlation 	0.27 with pvalue of 2E-158
# Ubiq and pTyr have correlation 	0.32 with pvalue of 7E-228
# pSer and pThr have correlation 	0.74 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.46 with pvalue of 0E+00
# pThr and pTyr have correlation 	0.45 with pvalue of 0E+00
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type pTyr
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.21 with pvalue of 3E-75
# GO and N6AK have correlation 	0.20 with pvalue of 2E-74
# GO and PTMs have correlation 	0.23 with pvalue of 8E-92
# GO and Sequence have correlation 	0.01 with pvalue of 6E-01
# GO and Ubiq have correlation 	0.27 with pvalue of 1E-129
# GO and pSer have correlation 	0.10 with pvalue of 3E-20
# GO and pThr have correlation 	0.16 with pvalue of 4E-47
# GO and pTyr have correlation 	0.20 with pvalue of 6E-73
# Mutations and N6AK have correlation 	0.08 with pvalue of 1E-11
# Mutations and PTMs have correlation 	0.10 with pvalue of 2E-18
# Mutations and Sequence have correlation 	0.21 with pvalue of 1E-78
# Mutations and Ubiq have correlation 	-0.01 with pvalue of 5E-01
# Mutations and pSer have correlation 	0.07 with pvalue of 5E-11
# Mutations and pThr have correlation 	0.11 with pvalue of 6E-22
# Mutations and pTyr have correlation 	0.10 with pvalue of 1E-18
# N6AK and PTMs have correlation 	0.55 with pvalue of 0E+00
# N6AK and Sequence have correlation 	0.14 with pvalue of 7E-35
# N6AK and Ubiq have correlation 	0.46 with pvalue of 0E+00
# N6AK and pSer have correlation 	0.29 with pvalue of 2E-150
# N6AK and pThr have correlation 	0.38 with pvalue of 3E-264
# N6AK and pTyr have correlation 	0.28 with pvalue of 6E-144
# PTMs and Sequence have correlation 	0.47 with pvalue of 0E+00
# PTMs and Ubiq have correlation 	0.51 with pvalue of 0E+00
# PTMs and pSer have correlation 	0.89 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.86 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.61 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.07 with pvalue of 3E-10
# Sequence and pSer have correlation 	0.49 with pvalue of 0E+00
# Sequence and pThr have correlation 	0.51 with pvalue of 0E+00
# Sequence and pTyr have correlation 	0.33 with pvalue of 2E-191
# Ubiq and pSer have correlation 	0.20 with pvalue of 2E-72
# Ubiq and pThr have correlation 	0.30 with pvalue of 7E-160
# Ubiq and pTyr have correlation 	0.26 with pvalue of 1E-123
# pSer and pThr have correlation 	0.79 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.46 with pvalue of 0E+00
# pThr and pTyr have correlation 	0.48 with pvalue of 0E+00
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type Ubiq
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.19 with pvalue of 5E-45
# GO and N6AK have correlation 	0.20 with pvalue of 5E-53
# GO and PTMs have correlation 	0.24 with pvalue of 9E-75
# GO and Sequence have correlation 	0.01 with pvalue of 5E-01
# GO and Ubiq have correlation 	0.23 with pvalue of 5E-67
# GO and pSer have correlation 	0.13 with pvalue of 1E-22
# GO and pThr have correlation 	0.18 with pvalue of 6E-44
# GO and pTyr have correlation 	0.24 with pvalue of 2E-72
# Mutations and N6AK have correlation 	0.07 with pvalue of 3E-08
# Mutations and PTMs have correlation 	0.12 with pvalue of 6E-21
# Mutations and Sequence have correlation 	0.19 with pvalue of 4E-49
# Mutations and Ubiq have correlation 	0.01 with pvalue of 5E-01
# Mutations and pSer have correlation 	0.12 with pvalue of 4E-19
# Mutations and pThr have correlation 	0.12 with pvalue of 4E-19
# Mutations and pTyr have correlation 	0.12 with pvalue of 1E-20
# N6AK and PTMs have correlation 	0.59 with pvalue of 0E+00
# N6AK and Sequence have correlation 	0.16 with pvalue of 2E-32
# N6AK and Ubiq have correlation 	0.45 with pvalue of 1E-284
# N6AK and pSer have correlation 	0.32 with pvalue of 3E-134
# N6AK and pThr have correlation 	0.40 with pvalue of 3E-213
# N6AK and pTyr have correlation 	0.35 with pvalue of 1E-163
# PTMs and Sequence have correlation 	0.53 with pvalue of 0E+00
# PTMs and Ubiq have correlation 	0.54 with pvalue of 0E+00
# PTMs and pSer have correlation 	0.89 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.87 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.67 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.17 with pvalue of 1E-39
# Sequence and pSer have correlation 	0.57 with pvalue of 0E+00
# Sequence and pThr have correlation 	0.55 with pvalue of 0E+00
# Sequence and pTyr have correlation 	0.40 with pvalue of 4E-223
# Ubiq and pSer have correlation 	0.23 with pvalue of 3E-71
# Ubiq and pThr have correlation 	0.32 with pvalue of 5E-138
# Ubiq and pTyr have correlation 	0.33 with pvalue of 2E-143
# pSer and pThr have correlation 	0.82 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.51 with pvalue of 0E+00
# pThr and pTyr have correlation 	0.54 with pvalue of 0E+00
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type N6AK
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.17 with pvalue of 8E-28
# GO and N6AK have correlation 	0.21 with pvalue of 3E-42
# GO and PTMs have correlation 	0.23 with pvalue of 1E-50
# GO and Sequence have correlation 	-0.01 with pvalue of 4E-01
# GO and Ubiq have correlation 	0.30 with pvalue of 8E-90
# GO and pSer have correlation 	0.09 with pvalue of 1E-08
# GO and pThr have correlation 	0.15 with pvalue of 4E-21
# GO and pTyr have correlation 	0.23 with pvalue of 2E-50
# Mutations and N6AK have correlation 	0.09 with pvalue of 9E-09
# Mutations and PTMs have correlation 	0.11 with pvalue of 7E-13
# Mutations and Sequence have correlation 	0.20 with pvalue of 8E-40
# Mutations and Ubiq have correlation 	-0.01 with pvalue of 4E-01
# Mutations and pSer have correlation 	0.09 with pvalue of 2E-09
# Mutations and pThr have correlation 	0.12 with pvalue of 3E-15
# Mutations and pTyr have correlation 	0.11 with pvalue of 2E-13
# N6AK and PTMs have correlation 	0.51 with pvalue of 6E-280
# N6AK and Sequence have correlation 	0.09 with pvalue of 3E-09
# N6AK and Ubiq have correlation 	0.41 with pvalue of 3E-168
# N6AK and pSer have correlation 	0.23 with pvalue of 2E-51
# N6AK and pThr have correlation 	0.33 with pvalue of 1E-106
# N6AK and pTyr have correlation 	0.31 with pvalue of 1E-94
# PTMs and Sequence have correlation 	0.50 with pvalue of 8E-261
# PTMs and Ubiq have correlation 	0.50 with pvalue of 2E-264
# PTMs and pSer have correlation 	0.88 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.86 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.65 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.06 with pvalue of 1E-04
# Sequence and pSer have correlation 	0.54 with pvalue of 8E-318
# Sequence and pThr have correlation 	0.54 with pvalue of 6E-319
# Sequence and pTyr have correlation 	0.39 with pvalue of 1E-150
# Ubiq and pSer have correlation 	0.17 with pvalue of 7E-29
# Ubiq and pThr have correlation 	0.27 with pvalue of 1E-70
# Ubiq and pTyr have correlation 	0.34 with pvalue of 2E-114
# pSer and pThr have correlation 	0.81 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.47 with pvalue of 5E-224
# pThr and pTyr have correlation 	0.52 with pvalue of 2E-281
#
# END OF SECTION

# %%
df.corr()
# Out:
#                  GO  Mutations      N6AK      PTMs  Sequence      Ubiq  \
# GO         1.000000   0.240477  0.227016  0.284875  0.036099  0.282170
# Mutations  0.240477   1.000000  0.086632  0.138824  0.183700  0.039465
# N6AK       0.227016   0.086632  1.000000  0.581113  0.163276  0.467986
# PTMs       0.284875   0.138824  0.581113  1.000000  0.454229  0.540966
# Sequence   0.036099   0.183700  0.163276  0.454229  1.000000  0.112101
# Ubiq       0.282170   0.039465  0.467986  0.540966  0.112101  1.000000
# pSer       0.169063   0.105632  0.340411  0.897825  0.466670  0.259644
# pThr       0.202182   0.125579  0.401603  0.851886  0.474667  0.328356
# pTyr       0.270115   0.145715  0.359014  0.676718  0.346619  0.349958
#
#                pSer      pThr      pTyr
# GO         0.169063  0.202182  0.270115
# Mutations  0.105632  0.125579  0.145715
# N6AK       0.340411  0.401603  0.359014
# PTMs       0.897825  0.851886  0.676718
# Sequence   0.466670  0.474667  0.346619
# Ubiq       0.259644  0.328356  0.349958
# pSer       1.000000  0.784271  0.514022
# pThr       0.784271  1.000000  0.525294
# pTyr       0.514022  0.525294  1.000000

# %% [markdown]
# # Correlation among pathogenic proteins

# %%
rArr = []
pArr = []
keys = df_path.columns

PTM_TYPES = ['pSer', 'pThr','pTyr','Ubiq','N6AK']

for PTM_TYPE in PTM_TYPES:
    
    # extract a subset of proteins where there is at least one modfication of the type
    # of interest
    subset = df_path[df_path[PTM_TYPE] > 1]
    
    # initialize the multiplot figure!
    idxCol = 0
    idxRow = 0
    s = ''
    print "------------------------------------------------------------"
    print "     Correlation analysis for PTM type %s (PATHOGENIC)"%PTM_TYPE
    print "------------------------------------------------------------"
    for i in range(0, len(keys)):
        key1 = keys[i]
        for j in range(i+1, len(keys)):
            key2 = keys[j]
            [r, p] = stats.pearsonr(subset[key1], subset[key2])
            rArr.append(r)
            pArr.append(p)
            s = "%s%s and %s have correlation \t%0.2f with pvalue of %0.E\n"%(s, key1, key2, r, p)
    print s
    print "END OF SECTION"
    print ""
# Out:
# ------------------------------------------------------------
#      Correlation analysis for PTM type pSer (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.17 with pvalue of 7E-05
# GO and N6AK have correlation 	0.08 with pvalue of 5E-02
# GO and PTMs have correlation 	0.27 with pvalue of 1E-10
# GO and Sequence have correlation 	0.09 with pvalue of 4E-02
# GO and Ubiq have correlation 	0.17 with pvalue of 4E-05
# GO and pSer have correlation 	0.23 with pvalue of 2E-08
# GO and pThr have correlation 	0.26 with pvalue of 6E-10
# GO and pTyr have correlation 	0.23 with pvalue of 6E-08
# Mutations and N6AK have correlation 	0.06 with pvalue of 1E-01
# Mutations and PTMs have correlation 	0.10 with pvalue of 2E-02
# Mutations and Sequence have correlation 	0.26 with pvalue of 3E-10
# Mutations and Ubiq have correlation 	-0.04 with pvalue of 3E-01
# Mutations and pSer have correlation 	0.09 with pvalue of 3E-02
# Mutations and pThr have correlation 	0.13 with pvalue of 2E-03
# Mutations and pTyr have correlation 	0.11 with pvalue of 8E-03
# N6AK and PTMs have correlation 	0.66 with pvalue of 1E-70
# N6AK and Sequence have correlation 	0.19 with pvalue of 4E-06
# N6AK and Ubiq have correlation 	0.35 with pvalue of 1E-17
# N6AK and pSer have correlation 	0.43 with pvalue of 3E-26
# N6AK and pThr have correlation 	0.53 with pvalue of 1E-42
# N6AK and pTyr have correlation 	0.42 with pvalue of 5E-26
# PTMs and Sequence have correlation 	0.49 with pvalue of 4E-36
# PTMs and Ubiq have correlation 	0.54 with pvalue of 2E-44
# PTMs and pSer have correlation 	0.89 with pvalue of 2E-189
# PTMs and pThr have correlation 	0.88 with pvalue of 2E-182
# PTMs and pTyr have correlation 	0.70 with pvalue of 3E-84
# Sequence and Ubiq have correlation 	0.07 with pvalue of 9E-02
# Sequence and pSer have correlation 	0.48 with pvalue of 6E-34
# Sequence and pThr have correlation 	0.58 with pvalue of 3E-51
# Sequence and pTyr have correlation 	0.46 with pvalue of 5E-31
# Ubiq and pSer have correlation 	0.36 with pvalue of 3E-18
# Ubiq and pThr have correlation 	0.37 with pvalue of 6E-20
# Ubiq and pTyr have correlation 	0.33 with pvalue of 4E-16
# pSer and pThr have correlation 	0.82 with pvalue of 1E-136
# pSer and pTyr have correlation 	0.55 with pvalue of 2E-45
# pThr and pTyr have correlation 	0.64 with pvalue of 1E-66
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type pThr (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.17 with pvalue of 3E-04
# GO and N6AK have correlation 	0.07 with pvalue of 2E-01
# GO and PTMs have correlation 	0.28 with pvalue of 4E-09
# GO and Sequence have correlation 	0.09 with pvalue of 8E-02
# GO and Ubiq have correlation 	0.19 with pvalue of 6E-05
# GO and pSer have correlation 	0.26 with pvalue of 6E-08
# GO and pThr have correlation 	0.26 with pvalue of 3E-08
# GO and pTyr have correlation 	0.23 with pvalue of 9E-07
# Mutations and N6AK have correlation 	0.04 with pvalue of 4E-01
# Mutations and PTMs have correlation 	0.08 with pvalue of 8E-02
# Mutations and Sequence have correlation 	0.26 with pvalue of 5E-08
# Mutations and Ubiq have correlation 	-0.07 with pvalue of 2E-01
# Mutations and pSer have correlation 	0.09 with pvalue of 8E-02
# Mutations and pThr have correlation 	0.11 with pvalue of 2E-02
# Mutations and pTyr have correlation 	0.10 with pvalue of 3E-02
# N6AK and PTMs have correlation 	0.64 with pvalue of 1E-50
# N6AK and Sequence have correlation 	0.15 with pvalue of 1E-03
# N6AK and Ubiq have correlation 	0.34 with pvalue of 6E-13
# N6AK and pSer have correlation 	0.41 with pvalue of 1E-18
# N6AK and pThr have correlation 	0.51 with pvalue of 2E-29
# N6AK and pTyr have correlation 	0.40 with pvalue of 3E-18
# PTMs and Sequence have correlation 	0.46 with pvalue of 1E-23
# PTMs and Ubiq have correlation 	0.54 with pvalue of 2E-33
# PTMs and pSer have correlation 	0.89 with pvalue of 8E-146
# PTMs and pThr have correlation 	0.87 with pvalue of 2E-132
# PTMs and pTyr have correlation 	0.69 with pvalue of 5E-61
# Sequence and Ubiq have correlation 	0.03 with pvalue of 5E-01
# Sequence and pSer have correlation 	0.46 with pvalue of 3E-23
# Sequence and pThr have correlation 	0.54 with pvalue of 8E-34
# Sequence and pTyr have correlation 	0.44 with pvalue of 4E-22
# Ubiq and pSer have correlation 	0.35 with pvalue of 5E-14
# Ubiq and pThr have correlation 	0.35 with pvalue of 6E-14
# Ubiq and pTyr have correlation 	0.32 with pvalue of 2E-11
# pSer and pThr have correlation 	0.82 with pvalue of 4E-106
# pSer and pTyr have correlation 	0.54 with pvalue of 2E-33
# pThr and pTyr have correlation 	0.62 with pvalue of 9E-48
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type pTyr (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.19 with pvalue of 9E-05
# GO and N6AK have correlation 	0.09 with pvalue of 7E-02
# GO and PTMs have correlation 	0.31 with pvalue of 3E-10
# GO and Sequence have correlation 	0.11 with pvalue of 2E-02
# GO and Ubiq have correlation 	0.20 with pvalue of 4E-05
# GO and pSer have correlation 	0.28 with pvalue of 6E-09
# GO and pThr have correlation 	0.30 with pvalue of 1E-09
# GO and pTyr have correlation 	0.23 with pvalue of 4E-06
# Mutations and N6AK have correlation 	0.07 with pvalue of 1E-01
# Mutations and PTMs have correlation 	0.12 with pvalue of 2E-02
# Mutations and Sequence have correlation 	0.27 with pvalue of 4E-08
# Mutations and Ubiq have correlation 	-0.07 with pvalue of 2E-01
# Mutations and pSer have correlation 	0.11 with pvalue of 2E-02
# Mutations and pThr have correlation 	0.15 with pvalue of 3E-03
# Mutations and pTyr have correlation 	0.09 with pvalue of 8E-02
# N6AK and PTMs have correlation 	0.67 with pvalue of 1E-54
# N6AK and Sequence have correlation 	0.20 with pvalue of 5E-05
# N6AK and Ubiq have correlation 	0.36 with pvalue of 3E-14
# N6AK and pSer have correlation 	0.47 with pvalue of 2E-23
# N6AK and pThr have correlation 	0.56 with pvalue of 3E-35
# N6AK and pTyr have correlation 	0.44 with pvalue of 1E-20
# PTMs and Sequence have correlation 	0.49 with pvalue of 4E-26
# PTMs and Ubiq have correlation 	0.55 with pvalue of 1E-33
# PTMs and pSer have correlation 	0.91 with pvalue of 1E-160
# PTMs and pThr have correlation 	0.90 with pvalue of 3E-148
# PTMs and pTyr have correlation 	0.70 with pvalue of 6E-61
# Sequence and Ubiq have correlation 	0.05 with pvalue of 3E-01
# Sequence and pSer have correlation 	0.48 with pvalue of 2E-25
# Sequence and pThr have correlation 	0.59 with pvalue of 6E-40
# Sequence and pTyr have correlation 	0.44 with pvalue of 2E-20
# Ubiq and pSer have correlation 	0.37 with pvalue of 1E-14
# Ubiq and pThr have correlation 	0.37 with pvalue of 2E-14
# Ubiq and pTyr have correlation 	0.30 with pvalue of 6E-10
# pSer and pThr have correlation 	0.83 with pvalue of 2E-106
# pSer and pTyr have correlation 	0.56 with pvalue of 2E-34
# pThr and pTyr have correlation 	0.65 with pvalue of 2E-50
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type Ubiq (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.19 with pvalue of 2E-03
# GO and N6AK have correlation 	0.04 with pvalue of 5E-01
# GO and PTMs have correlation 	0.24 with pvalue of 6E-05
# GO and Sequence have correlation 	0.08 with pvalue of 2E-01
# GO and Ubiq have correlation 	0.11 with pvalue of 8E-02
# GO and pSer have correlation 	0.22 with pvalue of 4E-04
# GO and pThr have correlation 	0.26 with pvalue of 1E-05
# GO and pTyr have correlation 	0.23 with pvalue of 2E-04
# Mutations and N6AK have correlation 	0.04 with pvalue of 6E-01
# Mutations and PTMs have correlation 	0.08 with pvalue of 2E-01
# Mutations and Sequence have correlation 	0.18 with pvalue of 3E-03
# Mutations and Ubiq have correlation 	-0.06 with pvalue of 4E-01
# Mutations and pSer have correlation 	0.10 with pvalue of 1E-01
# Mutations and pThr have correlation 	0.06 with pvalue of 4E-01
# Mutations and pTyr have correlation 	0.08 with pvalue of 2E-01
# N6AK and PTMs have correlation 	0.69 with pvalue of 1E-38
# N6AK and Sequence have correlation 	0.25 with pvalue of 4E-05
# N6AK and Ubiq have correlation 	0.39 with pvalue of 3E-11
# N6AK and pSer have correlation 	0.48 with pvalue of 6E-17
# N6AK and pThr have correlation 	0.53 with pvalue of 4E-21
# N6AK and pTyr have correlation 	0.43 with pvalue of 2E-13
# PTMs and Sequence have correlation 	0.54 with pvalue of 2E-21
# PTMs and Ubiq have correlation 	0.54 with pvalue of 3E-21
# PTMs and pSer have correlation 	0.91 with pvalue of 1E-103
# PTMs and pThr have correlation 	0.90 with pvalue of 1E-98
# PTMs and pTyr have correlation 	0.71 with pvalue of 2E-42
# Sequence and Ubiq have correlation 	0.07 with pvalue of 2E-01
# Sequence and pSer have correlation 	0.56 with pvalue of 2E-23
# Sequence and pThr have correlation 	0.64 with pvalue of 1E-31
# Sequence and pTyr have correlation 	0.47 with pvalue of 5E-16
# Ubiq and pSer have correlation 	0.33 with pvalue of 5E-08
# Ubiq and pThr have correlation 	0.37 with pvalue of 7E-10
# Ubiq and pTyr have correlation 	0.31 with pvalue of 2E-07
# pSer and pThr have correlation 	0.85 with pvalue of 7E-75
# pSer and pTyr have correlation 	0.57 with pvalue of 4E-24
# pThr and pTyr have correlation 	0.64 with pvalue of 1E-32
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type N6AK (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.15 with pvalue of 2E-02
# GO and N6AK have correlation 	0.06 with pvalue of 4E-01
# GO and PTMs have correlation 	0.25 with pvalue of 1E-04
# GO and Sequence have correlation 	0.09 with pvalue of 2E-01
# GO and Ubiq have correlation 	0.20 with pvalue of 3E-03
# GO and pSer have correlation 	0.22 with pvalue of 8E-04
# GO and pThr have correlation 	0.25 with pvalue of 2E-04
# GO and pTyr have correlation 	0.24 with pvalue of 3E-04
# Mutations and N6AK have correlation 	0.05 with pvalue of 4E-01
# Mutations and PTMs have correlation 	0.08 with pvalue of 3E-01
# Mutations and Sequence have correlation 	0.20 with pvalue of 2E-03
# Mutations and Ubiq have correlation 	-0.06 with pvalue of 4E-01
# Mutations and pSer have correlation 	0.08 with pvalue of 2E-01
# Mutations and pThr have correlation 	0.11 with pvalue of 1E-01
# Mutations and pTyr have correlation 	0.06 with pvalue of 3E-01
# N6AK and PTMs have correlation 	0.59 with pvalue of 4E-22
# N6AK and Sequence have correlation 	0.14 with pvalue of 4E-02
# N6AK and Ubiq have correlation 	0.27 with pvalue of 5E-05
# N6AK and pSer have correlation 	0.35 with pvalue of 8E-08
# N6AK and pThr have correlation 	0.47 with pvalue of 2E-13
# N6AK and pTyr have correlation 	0.40 with pvalue of 5E-10
# PTMs and Sequence have correlation 	0.51 with pvalue of 4E-16
# PTMs and Ubiq have correlation 	0.53 with pvalue of 2E-17
# PTMs and pSer have correlation 	0.89 with pvalue of 6E-79
# PTMs and pThr have correlation 	0.89 with pvalue of 2E-76
# PTMs and pTyr have correlation 	0.72 with pvalue of 3E-37
# Sequence and Ubiq have correlation 	0.06 with pvalue of 4E-01
# Sequence and pSer have correlation 	0.52 with pvalue of 5E-17
# Sequence and pThr have correlation 	0.60 with pvalue of 1E-23
# Sequence and pTyr have correlation 	0.48 with pvalue of 2E-14
# Ubiq and pSer have correlation 	0.35 with pvalue of 5E-08
# Ubiq and pThr have correlation 	0.36 with pvalue of 4E-08
# Ubiq and pTyr have correlation 	0.33 with pvalue of 6E-07
# pSer and pThr have correlation 	0.84 with pvalue of 3E-61
# pSer and pTyr have correlation 	0.60 with pvalue of 1E-23
# pThr and pTyr have correlation 	0.70 with pvalue of 1E-33
#
# END OF SECTION

# %%
# Out:
#                  GO  Mutations      N6AK      PTMs  Sequence      Ubiq  \
# GO         1.000000   0.210578  0.123334  0.239636  0.069526  0.140146
# Mutations  0.210578   1.000000  0.024575  0.110616  0.222019 -0.022471
# N6AK       0.123334   0.024575  1.000000  0.634143  0.208081  0.435195
# PTMs       0.239636   0.110616  0.634143  1.000000  0.512096  0.597670
# Sequence   0.069526   0.222019  0.208081  0.512096  1.000000  0.156149
# Ubiq       0.140146  -0.022471  0.435195  0.597670  0.156149  1.000000
# pSer       0.187661   0.110579  0.389492  0.887879  0.506751  0.338038
# pThr       0.201726   0.102761  0.468040  0.883267  0.560809  0.394544
# pTyr       0.235503   0.113451  0.370840  0.695211  0.453736  0.388037
#
#                pSer      pThr      pTyr
# GO         0.187661  0.201726  0.235503
# Mutations  0.110579  0.102761  0.113451
# N6AK       0.389492  0.468040  0.370840
# PTMs       0.887879  0.883267  0.695211
# Sequence   0.506751  0.560809  0.453736
# Ubiq       0.338038  0.394544  0.388037
# pSer       1.000000  0.839272  0.522992
# pThr       0.839272  1.000000  0.593555
# pTyr       0.522992  0.593555  1.000000

# %%
# Check to see if there is enrichment in set of proteins with pathogenic mutations for 
# increased likelihood of having other annotations

N = len(df['Sequence'])
n = len(df_path['Sequence'])
keys = df.columns
numThreshold = range(0, 30, 5)
for j in numThreshold:
    print "\nThreshold for terms > %d"%(j)
    for i in range(0, len(keys)-1):
   
        K_list = df[df[keys[i]]>j]
        k_list = df_path[df_path[keys[i]]>j]
        K = len(K_list[keys[i]])
        k = len(k_list[keys[i]])
        oddsratio, pvalue = stats.fisher_exact([[k, n-k], [K, N-K]], alternative='greater')
     
        print "%s:\t\t %0.E \t(N=%d, n=%d, K=%d, k=%d)"%(keys[i][0:5], pvalue, N, n, K, k)
# Out:
# Threshold for terms > 0
# GO:		 3E-255 	(N=21960, n=2273, K=15312, k=2224)
# Mutat:		 0E+00 	(N=21960, n=2273, K=11670, k=2273)
# PTMs:		 1E+00 	(N=21960, n=2273, K=21960, k=2273)
#
# Threshold for terms > 5
# GO:		 2E-275 	(N=21960, n=2273, K=9923, k=1884)
# Mutat:		 0E+00 	(N=21960, n=2273, K=2558, k=1315)
# PTMs:		 1E-50 	(N=21960, n=2273, K=12792, k=1682)
#
# Threshold for terms > 10
# GO:		 3E-184 	(N=21960, n=2273, K=5942, k=1311)
# Mutat:		 0E+00 	(N=21960, n=2273, K=1159, k=834)
# PTMs:		 2E-44 	(N=21960, n=2273, K=8441, k=1220)
#
# Threshold for terms > 15
# GO:		 1E-122 	(N=21960, n=2273, K=3459, k=851)
# Mutat:		 9E-269 	(N=21960, n=2273, K=719, k=583)
# PTMs:		 7E-36 	(N=21960, n=2273, K=5934, k=904)
#
# Threshold for terms > 20
# GO:		 1E-90 	(N=21960, n=2273, K=2131, k=578)
# Mutat:		 2E-197 	(N=21960, n=2273, K=496, k=425)
# PTMs:		 2E-31 	(N=21960, n=2273, K=4347, k=697)
#
# Threshold for terms > 25
# GO:		 2E-68 	(N=21960, n=2273, K=1388, k=405)
# Mutat:		 1E-167 	(N=21960, n=2273, K=399, k=356)
# PTMs:		 4E-26 	(N=21960, n=2273, K=3281, k=542)
