# %% [markdown]
# # Is there study bias on proteins with pathogenic mutations?
# Like with the other study bias code, we perform the same analysis her, except examining each induvidual modification separately.

# %%
# Setup the workspace, 
from proteomeScoutAPI import ProteomeScoutAPI
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from pylab import *
import pandas as pd
from scipy import stats 
import pickle

# set this to 0 if you would like to perform analysis on the entire set, 1 means we will remove extreme 
# outlier proteins in terms of lenght, GO annotations, mutations, or PTMS
FILTER = 1 
# %matplotlib inline

# define input file for ProteomeScout data
proteomeScoutFile = '../../data/proteomescout_everything_20151118.tsv'

# read in ProteomeScout data
PTM_API = ProteomeScoutAPI(proteomeScoutFile)

# read in pre-processed IDs to use
humanIds = pickle.load(open('parsed_unique_IDs.p','rb'))

# read in SwissProt mutations data 
SwissProtMuts = pickle.load(open('swissprot_mutations.p','rb'))

# %%
print "The number of proteins being examined is: %i" % (len(humanIds))
# Out:
# The number of proteins being examined is: 22589

# %%
# for every protein get the sequence, GO terms, PTMs and mutations
protDict = {}
for ID in humanIds:
    
    # for each protein ID extract the sequence, GO terms
    # PTMs, and any mutations from the SwissProtsmMuts dataset
    tempProtDict = {}
    tempProtDict['sequence'] = PTM_API.get_sequence(ID)
    tempProtDict['GO_terms'] = PTM_API.get_GO(ID)
    
    # if we find mutations set them, else set an empty
    # list
    if ID in SwissProtMuts:
        tempProtDict['mutations'] = SwissProtMuts[ID]
    else:
        tempProtDict['mutations'] = []
    tempProtDict['PTMs'] = PTM_API.get_PTMs(ID)
    
    # having created the record add it into the protDict
    # dictionary
    protDict[ID] = tempProtDict

# %% [markdown]
# ### Creating a PTM specific dataframe
# Having extracted all the raw data, we now iterate over each protein and extract out protein-specific results, including the number of each specific type of mutation (phosphoserine, phosphothreonine, phosphotyrosine, ubiquitin, and N6-acetyllysine).

# %%
# create matched vectors of our items of interest
num_GO = []
num_muts = []
num_PS = []
num_PT = []
num_PY = []
num_UB = []
num_NK = []
num_PTMs = []
seqLength = []
pathoStatus = []
protIds = []

# for each ID in the protein dictionary
for ID in protDict:
    val = 0
    
    # check if any of the mutations in this protein are associated with a disease
    # according to the SwissProt disease mutation annotation
    for m in protDict[ID]['mutations']:
            if m[3] == 'Disease':            
                val = 1
    
    # set the pathogenic states
    pathoStatus.append(val)
    
    ## increment the various lists with the number of 
    # GO terms
    num_GO.append(len(protDict[ID]['GO_terms']))
    
    # Mutations
    num_muts.append(len(protDict[ID]['mutations']))
    
    # All PTMs...
    num_PTMs.append(len(protDict[ID]['PTMs']))
    
    # >>>>>>>>>>>>>
    # initialize empty list
    # tempList[0] ==> Phosphoserine
    # tempList[1] ==> Phosphothereonine
    # tempList[2] ==> Phosphotyrosine
    # tempList[3] ==> Ubiquitination 
    # tempList[4] ==> N6-acetyllysine 
    tempList = [0,0,0,0,0]
    
    # get the set of PTMs from the record
    PTMList = protDict[ID]['PTMs']
    
    # for each record incremenet the appropriate counter
    for PTM in PTMList:
        if PTM[2] == 'Phosphoserine':
            tempList[0] = tempList[0]+1
            
        if PTM[2] == 'Phosphothreonine':
            tempList[1] = tempList[1]+1
            
        if PTM[2] == 'Phosphotyrosine':
            tempList[2] = tempList[2]+1
            
        if PTM[2] == 'Ubiquitination':
            tempList[3] = tempList[3]+1
            
        if PTM[2] == 'N6-acetyllysine':
            tempList[4] = tempList[4]+1
            
            
            
    num_PS.append(tempList[0])
    num_PT.append(tempList[1])
    num_PY.append(tempList[2])
    num_UB.append(tempList[3])
    num_NK.append(tempList[4])

    
    # Sequence length
    seqLength.append(len(protDict[ID]['sequence']))
    protIds.append(ID)
    
# build a PANDAs dataframe
df = pd.DataFrame({'GO': num_GO,
                   'Mutations': num_muts,
                   'PTMs': num_PTMs,
                   'pSer': num_PS,
                   'pThr': num_PT,
                   'pTyr': num_PY,
                   'Ubiq': num_UB,
                   'N6AK': num_NK,
                   'Sequence': seqLength})

pathoS = pd.Series(pathoStatus)
protId_S = pd.Series(protIds)
df.describe()
# Out:
#                  GO     Mutations          N6AK          PTMs      Sequence  \
# count  22244.000000  22244.000000  22244.000000  22244.000000  22244.000000
# mean       7.903120      3.171282      0.944569     14.283672    612.651502
# std       10.937723     14.429350      2.512037     23.357662    621.127045
# min        0.000000      0.000000      0.000000      1.000000     10.000000
# 25%        0.000000      0.000000      0.000000      3.000000    294.000000
# 50%        5.000000      1.000000      0.000000      8.000000    459.000000
# 75%       11.000000      3.000000      1.000000     17.000000    735.000000
# max      159.000000   1338.000000     75.000000   1240.000000  34350.000000
#
#                Ubiq          pSer          pThr          pTyr
# count  22244.000000  22244.000000  22244.000000  22244.000000
# mean       1.602634      5.991279      2.538392      1.721633
# std        4.070141     11.556111      4.756311      3.444046
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000      0.000000
# 50%        0.000000      2.000000      1.000000      1.000000
# 75%        2.000000      7.000000      3.000000      2.000000
# max      205.000000    547.000000    267.000000    294.000000

# %% [markdown]
# We can summarize the information for each protein by printing the dataframe, as shown below;

# %%
df
# Out:
#        GO  Mutations  N6AK  PTMs  Sequence  Ubiq  pSer  pThr  pTyr
# 0       0          0     0     1        38     0     0     0     1
# 1      11        102     4    25       574     4     8     1     4
# 2       2          3     0    11       661     0     3     1     2
# 3      13          0     1    24       476     0    12     7     3
# 4       0          0     0     5       192     0     4     1     0
# 5      16          4     1     8       752     0     1     3     1
# 6      13          1     3    19       418     1    13     0     1
# 7       4          0     0    16      1114     0    15     0     1
# 8       0          0     0     1       484     1     0     0     0
# 9      14          0     1    43      1055     0    27     6     8
# 10     24          0     0    30       346     0    18    10     1
# 11     14          1     2    23       439     5     8     2     5
# 12      2          1     0     1       420     0     1     0     0
# 13      8          8     0    19      1382     0     7     5     3
# 14      0         11     2    17      1359     0     5     4     2
# 15      0          0     0    12       987     0     1     1    10
# 16     10          1     0    10       430     0     9     0     1
# 17      2          0     0     4       434     0     3     0     1
# 18      1          1     0     4       198     0     3     0     1
# 19      9          0     0     3       115     0     1     0     0
# 20     19          7     0     5       583     2     0     0     0
# 21      7         21     0     2       347     0     0     1     1
# 22      0          0     1     9       823     0     5     3     0
# 23      8          7     0     2       115     0     1     0     1
# 24     35         64    44    96       609     2    14    13    15
# 25      9          3     1     9       201     0     0     0     2
# 26     14          5     2    18       367     1     7     1     1
# 27      8          0     4    15       102     1     7     1     0
# 28     12          0     1    15       432     9     1     1     2
# 29     11          0     0    13       384     1     8     3     1
# ...    ..        ...   ...   ...       ...   ...   ...   ...   ...
# 22214  11          0     0    23       390     8     7     4     0
# 22215   2          0     0    14       327     2     3     0     0
# 22216   0          0     0     6       329     2     1     1     2
# 22217  14          0     1     7       646     1     0     0     5
# 22218   0          1     1     6       341     0     2     2     1
# 22219   2          0     0     4       445     0     2     1     0
# 22220   1          0     0     7       200     1     3     0     3
# 22221   2          1     0     4       145     2     1     1     0
# 22222  20          6     0     5       312     0     2     3     0
# 22223   2          1     0    20       255     3     8     5     4
# 22224   3          0     0     3       582     0     3     0     0
# 22225  30          3     0     3        52     0     1     1     0
# 22226  12          2     0    12       619     2     5     3     1
# 22227   0          2     2     4       364     0     2     0     0
# 22228   0          1     0     6       510     0     0     2     4
# 22229   1          0     1     8       407     0     6     0     0
# 22230   0          0     0     7       696     0     3     0     4
# 22231  11          3     0     5       516     2     1     1     0
# 22232  26          2     0    14      1168     1     9     3     0
# 22233   3          2     4    32      1667     0    13    12     3
# 22234   0          0     0    21      1067     0    15     1     5
# 22235  11          5     0    33      1012     2    21     4     5
# 22236   1          0     0    10       604     0     2     6     0
# 22237  12          0     2    41       572     6    15     7     6
# 22238   0          0     0     5       730     0     4     1     0
# 22239   0          0     0     1       197     0     1     0     0
# 22240   4          0     0     8       490     1     2     1     2
# 22241  17          0     0     2       279     1     0     0     0
# 22242   1          2     1    11       212     1     3     4     0
# 22243   0          0     0     1       725     1     0     0     0
#
# [22244 rows x 9 columns]

# %% [markdown]
# ## Plotting 6-panel figures
# Having generated a summary record for each protein, we can now go and subselect the sample of proteins which have 1 or more modification of each type, and then ask how that subsample's properties are correlated with one another. For example, in proteins with one or more phosphotyrosine modification perhaps number of pTyr sites and GO are well correlated? Who knows - let's find out!

# %%
# set various initial parameters (can be modificed to change figure appearance)
nrows = 2
ncols = 3
SCATTER_SIZE=40
LABEL_SIZE = 8
ALPHA=0.2
BORDER_WIDTH=0.2
SHOW_LEGEND = False

# explicitly set tick labels to overide matplotlib's default spacing
TICKS = {'Mutations':np.arange(0,450,100), 'GO':np.arange(0,250,50), 'PTMs':np.arange(0,450,100),'Sequence':np.arange(0,12500,2500)}

# keep the same limits as used in the main text figure
LIMITS = {'GO':200, 'Mutations':400, 'PTMs':420,'Sequence':10000}
KEYS = ['Mutations', 'Sequence','GO']

PTM_TYPES = ['pSer', 'pThr','pTyr','Ubiq','N6AK']
KEY_PAIRS = [['Mutations','PTMs'],['PTMs','Sequence'],['Mutations','Sequence'],['GO','Mutations'],['GO','PTMs'],['GO','Sequence']]                                                        

# loop generates a 6 pannel subplot per modifictaion type
for PTM_TYPE in PTM_TYPES:
    
    # extract a subset of proteins where there is at least one modfication of the type
    # of interest
    subset = df[df[PTM_TYPE] > 1]
    
    # initialize the multiplot figure row and column indices
    idxCol = 0
    idxRow = 0

    fig, axes = plt.subplots(nrows=nrows, ncols=ncols)
    fig.tight_layout(pad=0.4, w_pad=2, h_pad=1.0)

    for KEY_PAIR in KEY_PAIRS:

        # set keys
        key1 = KEY_PAIR[0]
        key2 = KEY_PAIR[1]
        
        # if we're looking at a PTM replace the 'PTMs' keyword with the 
        # specific PTM we're looking at!
        PTMMODE=False
        if key2 == 'PTMs':
            key2_selector = PTM_TYPE
        else:
            key2_selector = key2
            
        if key1 == 'PTMs':
            key1_selector = PTM_TYPE
        else:
            key1_selector = key1
    
                    
        # draw the scatter plot (all and pathogenic protein)    
        axes[idxRow, idxCol].scatter(subset[key1_selector], subset[key2_selector], alpha=ALPHA, lw = BORDER_WIDTH,s=SCATTER_SIZE)
        axes[idxRow, idxCol].scatter(subset[key1_selector][pathoS==1], subset[key2_selector][pathoS==1], c='r',alpha=ALPHA, lw = BORDER_WIDTH, s=SCATTER_SIZE)
        
        # set the plot object to the current axis for direct manipulation of plt variables
        plt.sca(axes[idxRow, idxCol])
    
        
        plt.xlim([0,LIMITS[key1]])
        plt.ylim([0,LIMITS[key2]])
    
        plt.xticks(TICKS[key1])
        plt.yticks(TICKS[key2])

        # change name for plots
        if key1 == 'Sequence':
            key1 = 'Protein length'
        if key2 == 'Sequence':
            key2 = 'Protein length'
    
        plt.xlabel(key1,size=LABEL_SIZE)
        plt.ylabel(key2,size=LABEL_SIZE)
        plt.tick_params(axis='x', labelsize=8)
        plt.tick_params(axis='y', labelsize=8)
        if SHOW_LEGEND:
            legend([L1,L2], LEGEND_TEXT,frameon=False,scatterpoints = 1)

        # update the row and column counter, resetting
        idxCol = idxCol + 1
        if idxCol % (ncols) == 0:
            idxCol = 0
            idxRow += 1

    savefig("figures/6_panel_figure_%s.pdf"%(PTM_TYPE),bbox_inches='tight')

# %%
# create plots and calculate correlation
keys = df.columns
#pathoFilt = pathoStatus[indexes]
#%print len(pathoFilt)

if FILTER:
    dfFilt = df[(np.abs(stats.zscore(df)) < 20).all(axis=1)]
    indexes = df[(np.abs(stats.zscore(df)) < 20).all(axis=1)].index.tolist()
    pathoSFilt = pathoS[indexes]
    protIdsFilt = protId_S[indexes]
    df_path = dfFilt[:][pathoSFilt==1]
    df = dfFilt
    pathoS = pathoSFilt
    protId_S = protIdsFilt
    protId_pathoS = protId_S[pathoSFilt==1]
else:
    df_path = df[:][pathoS==1]  
    protId_pathoS = protId_S[pathoS==1]



df_path.describe()
df_path.sum()
# Out:
# GO             37880
# Mutations      36521
# N6AK            3760
# PTMs           46034
# Sequence     1728661
# Ubiq            5558
# pSer           16524
# pThr            7587
# pTyr            6255
# dtype: int64

# %% [markdown]
# # Correlation across all data
# #### NOTE:
# With dbSNP mutations data, all the p-values for correlation were very low (p < $10^{-10}$) but with the SwissProt set of mutations now a number of the p-values are larger (notable PTMs vs. sequence and PTMs vs. GO).

# %%
rArr = []
pArr = []
keys = df.columns
PTM_TYPES = ['pSer', 'pThr','pTyr','Ubiq','N6AK']

for PTM_TYPE in PTM_TYPES:
    
    # extract a subset of proteins where there is at least one modfication of the type
    # of interest
    subset = df[df[PTM_TYPE] > 1]
    
    # initialize the multiplot figure!
    idxCol = 0
    idxRow = 0
    
    print "------------------------------------------------------------"
    print "     Correlation analysis for PTM type %s"%PTM_TYPE
    print "------------------------------------------------------------"
    s = ''
    for i in range(0, len(keys)):
        key1 = keys[i]
        for j in range(i+1, len(keys)):
            key2 = keys[j]
            [r, p] = stats.pearsonr(subset[key1], subset[key2])
            rArr.append(r)
            pArr.append(p)
            s = "%s%s and %s have correlation \t%0.2f with pvalue of %0.E\n"%(s, key1, key2, r, p)
    print s
    print "END OF SECTION"
    print ""
# Out:
# ------------------------------------------------------------
#      Correlation analysis for PTM type pSer
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.22 with pvalue of 1E-151
# GO and N6AK have correlation 	0.21 with pvalue of 4E-143
# GO and PTMs have correlation 	0.26 with pvalue of 1E-206
# GO and Sequence have correlation 	0.01 with pvalue of 1E-01
# GO and Ubiq have correlation 	0.28 with pvalue of 4E-249
# GO and pSer have correlation 	0.12 with pvalue of 3E-46
# GO and pThr have correlation 	0.17 with pvalue of 1E-88
# GO and pTyr have correlation 	0.25 with pvalue of 5E-197
# Mutations and N6AK have correlation 	0.09 with pvalue of 1E-23
# Mutations and PTMs have correlation 	0.14 with pvalue of 6E-60
# Mutations and Sequence have correlation 	0.20 with pvalue of 4E-122
# Mutations and Ubiq have correlation 	0.02 with pvalue of 2E-02
# Mutations and pSer have correlation 	0.08 with pvalue of 2E-21
# Mutations and pThr have correlation 	0.11 with pvalue of 6E-40
# Mutations and pTyr have correlation 	0.13 with pvalue of 1E-54
# N6AK and PTMs have correlation 	0.56 with pvalue of 0E+00
# N6AK and Sequence have correlation 	0.14 with pvalue of 1E-62
# N6AK and Ubiq have correlation 	0.46 with pvalue of 0E+00
# N6AK and pSer have correlation 	0.30 with pvalue of 7E-280
# N6AK and pThr have correlation 	0.37 with pvalue of 0E+00
# N6AK and pTyr have correlation 	0.34 with pvalue of 0E+00
# PTMs and Sequence have correlation 	0.48 with pvalue of 0E+00
# PTMs and Ubiq have correlation 	0.51 with pvalue of 0E+00
# PTMs and pSer have correlation 	0.88 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.84 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.66 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.08 with pvalue of 4E-22
# Sequence and pSer have correlation 	0.46 with pvalue of 0E+00
# Sequence and pThr have correlation 	0.47 with pvalue of 0E+00
# Sequence and pTyr have correlation 	0.34 with pvalue of 0E+00
# Ubiq and pSer have correlation 	0.22 with pvalue of 4E-144
# Ubiq and pThr have correlation 	0.30 with pvalue of 8E-284
# Ubiq and pTyr have correlation 	0.33 with pvalue of 0E+00
# pSer and pThr have correlation 	0.77 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.47 with pvalue of 0E+00
# pThr and pTyr have correlation 	0.49 with pvalue of 0E+00
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type pThr
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.22 with pvalue of 1E-103
# GO and N6AK have correlation 	0.21 with pvalue of 9E-99
# GO and PTMs have correlation 	0.24 with pvalue of 1E-130
# GO and Sequence have correlation 	-0.00 with pvalue of 1E+00
# GO and Ubiq have correlation 	0.28 with pvalue of 4E-180
# GO and pSer have correlation 	0.11 with pvalue of 3E-28
# GO and pThr have correlation 	0.13 with pvalue of 2E-39
# GO and pTyr have correlation 	0.24 with pvalue of 6E-125
# Mutations and N6AK have correlation 	0.08 with pvalue of 1E-15
# Mutations and PTMs have correlation 	0.13 with pvalue of 9E-39
# Mutations and Sequence have correlation 	0.21 with pvalue of 2E-93
# Mutations and Ubiq have correlation 	0.01 with pvalue of 2E-01
# Mutations and pSer have correlation 	0.07 with pvalue of 2E-13
# Mutations and pThr have correlation 	0.10 with pvalue of 7E-23
# Mutations and pTyr have correlation 	0.13 with pvalue of 5E-39
# N6AK and PTMs have correlation 	0.55 with pvalue of 0E+00
# N6AK and Sequence have correlation 	0.12 with pvalue of 8E-33
# N6AK and Ubiq have correlation 	0.47 with pvalue of 0E+00
# N6AK and pSer have correlation 	0.28 with pvalue of 2E-174
# N6AK and pThr have correlation 	0.35 with pvalue of 2E-272
# N6AK and pTyr have correlation 	0.32 with pvalue of 3E-235
# PTMs and Sequence have correlation 	0.46 with pvalue of 0E+00
# PTMs and Ubiq have correlation 	0.50 with pvalue of 0E+00
# PTMs and pSer have correlation 	0.88 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.82 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.64 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.06 with pvalue of 8E-10
# Sequence and pSer have correlation 	0.44 with pvalue of 0E+00
# Sequence and pThr have correlation 	0.44 with pvalue of 0E+00
# Sequence and pTyr have correlation 	0.33 with pvalue of 2E-238
# Ubiq and pSer have correlation 	0.20 with pvalue of 4E-86
# Ubiq and pThr have correlation 	0.27 with pvalue of 5E-156
# Ubiq and pTyr have correlation 	0.31 with pvalue of 8E-222
# pSer and pThr have correlation 	0.74 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.46 with pvalue of 0E+00
# pThr and pTyr have correlation 	0.45 with pvalue of 0E+00
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type pTyr
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.22 with pvalue of 1E-81
# GO and N6AK have correlation 	0.20 with pvalue of 2E-73
# GO and PTMs have correlation 	0.23 with pvalue of 1E-92
# GO and Sequence have correlation 	0.01 with pvalue of 5E-01
# GO and Ubiq have correlation 	0.27 with pvalue of 1E-125
# GO and pSer have correlation 	0.10 with pvalue of 1E-19
# GO and pThr have correlation 	0.16 with pvalue of 1E-44
# GO and pTyr have correlation 	0.20 with pvalue of 2E-69
# Mutations and N6AK have correlation 	0.07 with pvalue of 4E-11
# Mutations and PTMs have correlation 	0.12 with pvalue of 3E-28
# Mutations and Sequence have correlation 	0.21 with pvalue of 1E-79
# Mutations and Ubiq have correlation 	-0.01 with pvalue of 6E-01
# Mutations and pSer have correlation 	0.08 with pvalue of 3E-11
# Mutations and pThr have correlation 	0.11 with pvalue of 2E-21
# Mutations and pTyr have correlation 	0.11 with pvalue of 3E-21
# N6AK and PTMs have correlation 	0.55 with pvalue of 0E+00
# N6AK and Sequence have correlation 	0.14 with pvalue of 3E-34
# N6AK and Ubiq have correlation 	0.46 with pvalue of 0E+00
# N6AK and pSer have correlation 	0.29 with pvalue of 2E-148
# N6AK and pThr have correlation 	0.38 with pvalue of 2E-261
# N6AK and pTyr have correlation 	0.29 with pvalue of 1E-146
# PTMs and Sequence have correlation 	0.50 with pvalue of 0E+00
# PTMs and Ubiq have correlation 	0.50 with pvalue of 0E+00
# PTMs and pSer have correlation 	0.88 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.86 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.61 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.07 with pvalue of 9E-11
# Sequence and pSer have correlation 	0.48 with pvalue of 0E+00
# Sequence and pThr have correlation 	0.51 with pvalue of 0E+00
# Sequence and pTyr have correlation 	0.33 with pvalue of 1E-189
# Ubiq and pSer have correlation 	0.20 with pvalue of 1E-72
# Ubiq and pThr have correlation 	0.30 with pvalue of 6E-159
# Ubiq and pTyr have correlation 	0.26 with pvalue of 1E-121
# pSer and pThr have correlation 	0.79 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.46 with pvalue of 0E+00
# pThr and pTyr have correlation 	0.48 with pvalue of 0E+00
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type Ubiq
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.19 with pvalue of 1E-47
# GO and N6AK have correlation 	0.20 with pvalue of 9E-54
# GO and PTMs have correlation 	0.24 with pvalue of 8E-73
# GO and Sequence have correlation 	0.01 with pvalue of 7E-01
# GO and Ubiq have correlation 	0.23 with pvalue of 1E-65
# GO and pSer have correlation 	0.13 with pvalue of 4E-21
# GO and pThr have correlation 	0.18 with pvalue of 1E-41
# GO and pTyr have correlation 	0.23 with pvalue of 1E-69
# Mutations and N6AK have correlation 	0.07 with pvalue of 4E-08
# Mutations and PTMs have correlation 	0.13 with pvalue of 2E-23
# Mutations and Sequence have correlation 	0.20 with pvalue of 1E-49
# Mutations and Ubiq have correlation 	0.01 with pvalue of 3E-01
# Mutations and pSer have correlation 	0.12 with pvalue of 2E-19
# Mutations and pThr have correlation 	0.12 with pvalue of 3E-18
# Mutations and pTyr have correlation 	0.13 with pvalue of 2E-22
# N6AK and PTMs have correlation 	0.59 with pvalue of 0E+00
# N6AK and Sequence have correlation 	0.16 with pvalue of 9E-32
# N6AK and Ubiq have correlation 	0.45 with pvalue of 1E-280
# N6AK and pSer have correlation 	0.32 with pvalue of 3E-131
# N6AK and pThr have correlation 	0.40 with pvalue of 2E-210
# N6AK and pTyr have correlation 	0.36 with pvalue of 2E-167
# PTMs and Sequence have correlation 	0.54 with pvalue of 0E+00
# PTMs and Ubiq have correlation 	0.54 with pvalue of 0E+00
# PTMs and pSer have correlation 	0.88 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.87 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.68 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.18 with pvalue of 8E-41
# Sequence and pSer have correlation 	0.57 with pvalue of 0E+00
# Sequence and pThr have correlation 	0.56 with pvalue of 0E+00
# Sequence and pTyr have correlation 	0.41 with pvalue of 2E-225
# Ubiq and pSer have correlation 	0.23 with pvalue of 8E-71
# Ubiq and pThr have correlation 	0.32 with pvalue of 3E-138
# Ubiq and pTyr have correlation 	0.33 with pvalue of 7E-146
# pSer and pThr have correlation 	0.82 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.51 with pvalue of 0E+00
# pThr and pTyr have correlation 	0.53 with pvalue of 0E+00
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type N6AK
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.18 with pvalue of 2E-30
# GO and N6AK have correlation 	0.21 with pvalue of 3E-42
# GO and PTMs have correlation 	0.23 with pvalue of 5E-49
# GO and Sequence have correlation 	-0.01 with pvalue of 3E-01
# GO and Ubiq have correlation 	0.30 with pvalue of 2E-87
# GO and pSer have correlation 	0.09 with pvalue of 3E-08
# GO and pThr have correlation 	0.14 with pvalue of 6E-20
# GO and pTyr have correlation 	0.22 with pvalue of 4E-48
# Mutations and N6AK have correlation 	0.09 with pvalue of 2E-09
# Mutations and PTMs have correlation 	0.12 with pvalue of 3E-14
# Mutations and Sequence have correlation 	0.20 with pvalue of 3E-39
# Mutations and Ubiq have correlation 	-0.01 with pvalue of 5E-01
# Mutations and pSer have correlation 	0.09 with pvalue of 5E-09
# Mutations and pThr have correlation 	0.12 with pvalue of 7E-15
# Mutations and pTyr have correlation 	0.12 with pvalue of 7E-14
# N6AK and PTMs have correlation 	0.51 with pvalue of 2E-271
# N6AK and Sequence have correlation 	0.09 with pvalue of 2E-09
# N6AK and Ubiq have correlation 	0.41 with pvalue of 9E-165
# N6AK and pSer have correlation 	0.23 with pvalue of 3E-50
# N6AK and pThr have correlation 	0.33 with pvalue of 2E-105
# N6AK and pTyr have correlation 	0.31 with pvalue of 1E-93
# PTMs and Sequence have correlation 	0.51 with pvalue of 1E-270
# PTMs and Ubiq have correlation 	0.50 with pvalue of 4E-259
# PTMs and pSer have correlation 	0.88 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.86 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.65 with pvalue of 0E+00
# Sequence and Ubiq have correlation 	0.06 with pvalue of 7E-05
# Sequence and pSer have correlation 	0.54 with pvalue of 2E-312
# Sequence and pThr have correlation 	0.54 with pvalue of 4E-314
# Sequence and pTyr have correlation 	0.39 with pvalue of 2E-149
# Ubiq and pSer have correlation 	0.17 with pvalue of 4E-29
# Ubiq and pThr have correlation 	0.27 with pvalue of 7E-71
# Ubiq and pTyr have correlation 	0.34 with pvalue of 4E-114
# pSer and pThr have correlation 	0.81 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.46 with pvalue of 2E-217
# pThr and pTyr have correlation 	0.51 with pvalue of 6E-273
#
# END OF SECTION

# %%
df.corr()
# Out:
#                  GO  Mutations      N6AK      PTMs  Sequence      Ubiq  \
# GO         1.000000   0.232134  0.226276  0.287245  0.040853  0.277468
# Mutations  0.232134   1.000000  0.094509  0.154453  0.188625  0.031222
# N6AK       0.226276   0.094509  1.000000  0.576654  0.172102  0.464607
# PTMs       0.287245   0.154453  0.576654  1.000000  0.492451  0.533510
# Sequence   0.040853   0.188625  0.172102  0.492451  1.000000  0.121203
# Ubiq       0.277468   0.031222  0.464607  0.533510  0.121203  1.000000
# pSer       0.167630   0.099984  0.343688  0.891806  0.475398  0.263216
# pThr       0.197152   0.124641  0.404503  0.852682  0.481807  0.327041
# pTyr       0.266299   0.142661  0.365758  0.682193  0.359639  0.351130
#
#                pSer      pThr      pTyr
# GO         0.167630  0.197152  0.266299
# Mutations  0.099984  0.124641  0.142661
# N6AK       0.343688  0.404503  0.365758
# PTMs       0.891806  0.852682  0.682193
# Sequence   0.475398  0.481807  0.359639
# Ubiq       0.263216  0.327041  0.351130
# pSer       1.000000  0.782741  0.513603
# pThr       0.782741  1.000000  0.520874
# pTyr       0.513603  0.520874  1.000000

# %% [markdown]
# # Correlation among pathogenic proteins

# %%
rArr = []
pArr = []
keys = df_path.columns

PTM_TYPES = ['pSer', 'pThr','pTyr','Ubiq','N6AK']

for PTM_TYPE in PTM_TYPES:
    
    # extract a subset of proteins where there is at least one modfication of the type
    # of interest
    subset = df_path[df_path[PTM_TYPE] > 1]
    
    # initialize the multiplot figure!
    idxCol = 0
    idxRow = 0
    s = ''
    print "------------------------------------------------------------"
    print "     Correlation analysis for PTM type %s (PATHOGENIC)"%PTM_TYPE
    print "------------------------------------------------------------"
    for i in range(0, len(keys)):
        key1 = keys[i]
        for j in range(i+1, len(keys)):
            key2 = keys[j]
            [r, p] = stats.pearsonr(subset[key1], subset[key2])
            rArr.append(r)
            pArr.append(p)
            s = "%s%s and %s have correlation \t%0.2f with pvalue of %0.E\n"%(s, key1, key2, r, p)
    print s
    print "END OF SECTION"
    print ""
# Out:
# ------------------------------------------------------------
#      Correlation analysis for PTM type pSer (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.21 with pvalue of 3E-17
# GO and N6AK have correlation 	0.11 with pvalue of 8E-06
# GO and PTMs have correlation 	0.23 with pvalue of 8E-22
# GO and Sequence have correlation 	0.05 with pvalue of 6E-02
# GO and Ubiq have correlation 	0.12 with pvalue of 4E-07
# GO and pSer have correlation 	0.17 with pvalue of 1E-12
# GO and pThr have correlation 	0.19 with pvalue of 5E-15
# GO and pTyr have correlation 	0.23 with pvalue of 9E-22
# Mutations and N6AK have correlation 	0.04 with pvalue of 7E-02
# Mutations and PTMs have correlation 	0.15 with pvalue of 3E-09
# Mutations and Sequence have correlation 	0.23 with pvalue of 2E-21
# Mutations and Ubiq have correlation 	-0.05 with pvalue of 6E-02
# Mutations and pSer have correlation 	0.10 with pvalue of 3E-05
# Mutations and pThr have correlation 	0.12 with pvalue of 8E-07
# Mutations and pTyr have correlation 	0.12 with pvalue of 6E-07
# N6AK and PTMs have correlation 	0.61 with pvalue of 2E-169
# N6AK and Sequence have correlation 	0.17 with pvalue of 1E-11
# N6AK and Ubiq have correlation 	0.41 with pvalue of 5E-68
# N6AK and pSer have correlation 	0.36 with pvalue of 3E-53
# N6AK and pThr have correlation 	0.46 with pvalue of 4E-88
# N6AK and pTyr have correlation 	0.36 with pvalue of 2E-52
# PTMs and Sequence have correlation 	0.52 with pvalue of 5E-117
# PTMs and Ubiq have correlation 	0.55 with pvalue of 2E-133
# PTMs and pSer have correlation 	0.86 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.87 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.68 with pvalue of 9E-228
# Sequence and Ubiq have correlation 	0.11 with pvalue of 4E-06
# Sequence and pSer have correlation 	0.46 with pvalue of 2E-87
# Sequence and pThr have correlation 	0.53 with pvalue of 3E-120
# Sequence and pTyr have correlation 	0.43 with pvalue of 4E-74
# Ubiq and pSer have correlation 	0.30 with pvalue of 4E-36
# Ubiq and pThr have correlation 	0.36 with pvalue of 2E-51
# Ubiq and pTyr have correlation 	0.36 with pvalue of 1E-52
# pSer and pThr have correlation 	0.82 with pvalue of 0E+00
# pSer and pTyr have correlation 	0.48 with pvalue of 3E-96
# pThr and pTyr have correlation 	0.56 with pvalue of 6E-139
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type pThr (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.21 with pvalue of 2E-14
# GO and N6AK have correlation 	0.11 with pvalue of 2E-04
# GO and PTMs have correlation 	0.22 with pvalue of 6E-16
# GO and Sequence have correlation 	0.03 with pvalue of 3E-01
# GO and Ubiq have correlation 	0.12 with pvalue of 2E-05
# GO and pSer have correlation 	0.18 with pvalue of 2E-10
# GO and pThr have correlation 	0.18 with pvalue of 1E-10
# GO and pTyr have correlation 	0.21 with pvalue of 2E-14
# Mutations and N6AK have correlation 	0.04 with pvalue of 2E-01
# Mutations and PTMs have correlation 	0.15 with pvalue of 2E-07
# Mutations and Sequence have correlation 	0.24 with pvalue of 2E-17
# Mutations and Ubiq have correlation 	-0.05 with pvalue of 6E-02
# Mutations and pSer have correlation 	0.10 with pvalue of 2E-04
# Mutations and pThr have correlation 	0.12 with pvalue of 3E-05
# Mutations and pTyr have correlation 	0.14 with pvalue of 1E-06
# N6AK and PTMs have correlation 	0.60 with pvalue of 7E-126
# N6AK and Sequence have correlation 	0.14 with pvalue of 6E-07
# N6AK and Ubiq have correlation 	0.42 with pvalue of 8E-54
# N6AK and pSer have correlation 	0.35 with pvalue of 2E-38
# N6AK and pThr have correlation 	0.45 with pvalue of 3E-63
# N6AK and pTyr have correlation 	0.36 with pvalue of 9E-40
# PTMs and Sequence have correlation 	0.49 with pvalue of 3E-78
# PTMs and Ubiq have correlation 	0.55 with pvalue of 5E-100
# PTMs and pSer have correlation 	0.86 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.86 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.68 with pvalue of 7E-170
# Sequence and Ubiq have correlation 	0.08 with pvalue of 3E-03
# Sequence and pSer have correlation 	0.44 with pvalue of 1E-60
# Sequence and pThr have correlation 	0.49 with pvalue of 7E-79
# Sequence and pTyr have correlation 	0.41 with pvalue of 2E-52
# Ubiq and pSer have correlation 	0.30 with pvalue of 9E-27
# Ubiq and pThr have correlation 	0.35 with pvalue of 3E-37
# Ubiq and pTyr have correlation 	0.36 with pvalue of 5E-40
# pSer and pThr have correlation 	0.82 with pvalue of 2E-309
# pSer and pTyr have correlation 	0.48 with pvalue of 6E-74
# pThr and pTyr have correlation 	0.55 with pvalue of 3E-102
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type pTyr (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.22 with pvalue of 7E-14
# GO and N6AK have correlation 	0.11 with pvalue of 9E-05
# GO and PTMs have correlation 	0.25 with pvalue of 2E-17
# GO and Sequence have correlation 	0.05 with pvalue of 1E-01
# GO and Ubiq have correlation 	0.11 with pvalue of 2E-04
# GO and pSer have correlation 	0.19 with pvalue of 4E-11
# GO and pThr have correlation 	0.21 with pvalue of 6E-13
# GO and pTyr have correlation 	0.24 with pvalue of 4E-17
# Mutations and N6AK have correlation 	0.04 with pvalue of 2E-01
# Mutations and PTMs have correlation 	0.16 with pvalue of 9E-08
# Mutations and Sequence have correlation 	0.24 with pvalue of 1E-16
# Mutations and Ubiq have correlation 	-0.06 with pvalue of 3E-02
# Mutations and pSer have correlation 	0.12 with pvalue of 4E-05
# Mutations and pThr have correlation 	0.14 with pvalue of 4E-06
# Mutations and pTyr have correlation 	0.12 with pvalue of 7E-05
# N6AK and PTMs have correlation 	0.60 with pvalue of 2E-112
# N6AK and Sequence have correlation 	0.15 with pvalue of 2E-07
# N6AK and Ubiq have correlation 	0.42 with pvalue of 2E-51
# N6AK and pSer have correlation 	0.35 with pvalue of 5E-35
# N6AK and pThr have correlation 	0.45 with pvalue of 4E-59
# N6AK and pTyr have correlation 	0.34 with pvalue of 7E-33
# PTMs and Sequence have correlation 	0.52 with pvalue of 1E-79
# PTMs and Ubiq have correlation 	0.56 with pvalue of 9E-98
# PTMs and pSer have correlation 	0.88 with pvalue of 0E+00
# PTMs and pThr have correlation 	0.88 with pvalue of 0E+00
# PTMs and pTyr have correlation 	0.68 with pvalue of 5E-157
# Sequence and Ubiq have correlation 	0.09 with pvalue of 1E-03
# Sequence and pSer have correlation 	0.47 with pvalue of 1E-63
# Sequence and pThr have correlation 	0.54 with pvalue of 3E-88
# Sequence and pTyr have correlation 	0.40 with pvalue of 2E-44
# Ubiq and pSer have correlation 	0.32 with pvalue of 1E-28
# Ubiq and pThr have correlation 	0.36 with pvalue of 7E-37
# Ubiq and pTyr have correlation 	0.33 with pvalue of 2E-30
# pSer and pThr have correlation 	0.82 with pvalue of 1E-285
# pSer and pTyr have correlation 	0.51 with pvalue of 1E-76
# pThr and pTyr have correlation 	0.58 with pvalue of 1E-102
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type Ubiq (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.21 with pvalue of 2E-09
# GO and N6AK have correlation 	0.09 with pvalue of 1E-02
# GO and PTMs have correlation 	0.21 with pvalue of 3E-09
# GO and Sequence have correlation 	0.01 with pvalue of 8E-01
# GO and Ubiq have correlation 	0.09 with pvalue of 1E-02
# GO and pSer have correlation 	0.15 with pvalue of 1E-05
# GO and pThr have correlation 	0.20 with pvalue of 1E-08
# GO and pTyr have correlation 	0.20 with pvalue of 6E-09
# Mutations and N6AK have correlation 	0.03 with pvalue of 3E-01
# Mutations and PTMs have correlation 	0.12 with pvalue of 5E-04
# Mutations and Sequence have correlation 	0.18 with pvalue of 2E-07
# Mutations and Ubiq have correlation 	-0.04 with pvalue of 3E-01
# Mutations and pSer have correlation 	0.14 with pvalue of 6E-05
# Mutations and pThr have correlation 	0.09 with pvalue of 9E-03
# Mutations and pTyr have correlation 	0.12 with pvalue of 6E-04
# N6AK and PTMs have correlation 	0.64 with pvalue of 2E-94
# N6AK and Sequence have correlation 	0.19 with pvalue of 8E-08
# N6AK and Ubiq have correlation 	0.43 with pvalue of 2E-37
# N6AK and pSer have correlation 	0.40 with pvalue of 5E-32
# N6AK and pThr have correlation 	0.47 with pvalue of 4E-45
# N6AK and pTyr have correlation 	0.35 with pvalue of 7E-25
# PTMs and Sequence have correlation 	0.53 with pvalue of 8E-61
# PTMs and Ubiq have correlation 	0.58 with pvalue of 7E-74
# PTMs and pSer have correlation 	0.89 with pvalue of 1E-279
# PTMs and pThr have correlation 	0.89 with pvalue of 8E-284
# PTMs and pTyr have correlation 	0.69 with pvalue of 1E-116
# Sequence and Ubiq have correlation 	0.18 with pvalue of 4E-07
# Sequence and pSer have correlation 	0.54 with pvalue of 3E-63
# Sequence and pThr have correlation 	0.58 with pvalue of 6E-74
# Sequence and pTyr have correlation 	0.45 with pvalue of 5E-42
# Ubiq and pSer have correlation 	0.31 with pvalue of 6E-19
# Ubiq and pThr have correlation 	0.38 with pvalue of 1E-28
# Ubiq and pTyr have correlation 	0.37 with pvalue of 5E-28
# pSer and pThr have correlation 	0.86 with pvalue of 7E-235
# pSer and pTyr have correlation 	0.51 with pvalue of 8E-56
# pThr and pTyr have correlation 	0.58 with pvalue of 4E-75
#
# END OF SECTION
#
# ------------------------------------------------------------
#      Correlation analysis for PTM type N6AK (PATHOGENIC)
# ------------------------------------------------------------
# GO and Mutations have correlation 	0.20 with pvalue of 3E-07
# GO and N6AK have correlation 	0.11 with pvalue of 4E-03
# GO and PTMs have correlation 	0.22 with pvalue of 1E-08
# GO and Sequence have correlation 	0.04 with pvalue of 3E-01
# GO and Ubiq have correlation 	0.14 with pvalue of 4E-04
# GO and pSer have correlation 	0.16 with pvalue of 5E-05
# GO and pThr have correlation 	0.20 with pvalue of 6E-07
# GO and pTyr have correlation 	0.22 with pvalue of 3E-08
# Mutations and N6AK have correlation 	0.06 with pvalue of 1E-01
# Mutations and PTMs have correlation 	0.10 with pvalue of 1E-02
# Mutations and Sequence have correlation 	0.20 with pvalue of 4E-07
# Mutations and Ubiq have correlation 	-0.06 with pvalue of 1E-01
# Mutations and pSer have correlation 	0.10 with pvalue of 1E-02
# Mutations and pThr have correlation 	0.12 with pvalue of 4E-03
# Mutations and pTyr have correlation 	0.09 with pvalue of 2E-02
# N6AK and PTMs have correlation 	0.58 with pvalue of 1E-57
# N6AK and Sequence have correlation 	0.15 with pvalue of 2E-04
# N6AK and Ubiq have correlation 	0.33 with pvalue of 6E-18
# N6AK and pSer have correlation 	0.32 with pvalue of 1E-16
# N6AK and pThr have correlation 	0.43 with pvalue of 5E-30
# N6AK and pTyr have correlation 	0.35 with pvalue of 1E-19
# PTMs and Sequence have correlation 	0.50 with pvalue of 2E-42
# PTMs and Ubiq have correlation 	0.54 with pvalue of 1E-50
# PTMs and pSer have correlation 	0.88 with pvalue of 3E-210
# PTMs and pThr have correlation 	0.88 with pvalue of 8E-214
# PTMs and pTyr have correlation 	0.69 with pvalue of 2E-92
# Sequence and Ubiq have correlation 	0.10 with pvalue of 9E-03
# Sequence and pSer have correlation 	0.50 with pvalue of 3E-41
# Sequence and pThr have correlation 	0.55 with pvalue of 5E-52
# Sequence and pTyr have correlation 	0.47 with pvalue of 4E-36
# Ubiq and pSer have correlation 	0.28 with pvalue of 7E-13
# Ubiq and pThr have correlation 	0.32 with pvalue of 8E-17
# Ubiq and pTyr have correlation 	0.38 with pvalue of 2E-23
# pSer and pThr have correlation 	0.86 with pvalue of 8E-185
# pSer and pTyr have correlation 	0.52 with pvalue of 5E-45
# pThr and pTyr have correlation 	0.61 with pvalue of 6E-66
#
# END OF SECTION

# %%
# Check to see if there is enrichment in set of proteins with pathogenic mutations for 
# increased likelihood of having other annotations

N = len(df['Sequence'])
n = len(df_path['Sequence'])
keys = df.columns
numThreshold = range(0, 30, 5)
for j in numThreshold:
    print "\nThreshold for terms > %d"%(j)
    for i in range(0, len(keys)-1):
   
        K_list = df[df[keys[i]]>j]
        k_list = df_path[df_path[keys[i]]>j]
        K = len(K_list[keys[i]])
        k = len(k_list[keys[i]])
        oddsratio, pvalue = stats.fisher_exact([[k, n-k], [K, N-K]], alternative='greater')
     
        print "%s:\t\t %0.E \t(N=%d, n=%d, K=%d, k=%d)"%(keys[i][0:5], pvalue, N, n, K, k)
# Out:
# Threshold for terms > 0
# GO:		 1E-246 	(N=22231, n=2300, K=15679, k=2249)
# Mutat:		 0E+00 	(N=22231, n=2300, K=12051, k=2300)
# N6AK:		 2E-26 	(N=22231, n=2300, K=7158, k=997)
# PTMs:		 1E+00 	(N=22231, n=2300, K=22231, k=2300)
# Seque:		 1E+00 	(N=22231, n=2300, K=22231, k=2300)
# Ubiq:		 2E-24 	(N=22231, n=2300, K=8830, k=1167)
# pSer:		 2E-21 	(N=22231, n=2300, K=17645, k=2007)
# pThr:		 1E-20 	(N=22231, n=2300, K=14506, k=1717)
#
# Threshold for terms > 5
# GO:		 1E-272 	(N=22231, n=2300, K=10106, k=1903)
# Mutat:		 0E+00 	(N=22231, n=2300, K=2632, k=1331)
# N6AK:		 1E-19 	(N=22231, n=2300, K=821, k=185)
# PTMs:		 6E-53 	(N=22231, n=2300, K=13338, k=1744)
# Seque:		 1E+00 	(N=22231, n=2300, K=22231, k=2300)
# Ubiq:		 6E-13 	(N=22231, n=2300, K=1875, k=302)
# pSer:		 1E-13 	(N=22231, n=2300, K=6502, k=845)
# pThr:		 1E-08 	(N=22231, n=2300, K=2831, k=392)
#
# Threshold for terms > 10
# GO:		 2E-185 	(N=22231, n=2300, K=5993, k=1322)
# Mutat:		 0E+00 	(N=22231, n=2300, K=1187, k=840)
# N6AK:		 9E-13 	(N=22231, n=2300, K=233, k=70)
# PTMs:		 1E-46 	(N=22231, n=2300, K=8852, k=1274)
# Seque:		 9E-01 	(N=22231, n=2300, K=22230, k=2300)
# Ubiq:		 1E-09 	(N=22231, n=2300, K=685, k=130)
# pSer:		 3E-07 	(N=22231, n=2300, K=3466, k=454)
# pThr:		 3E-06 	(N=22231, n=2300, K=965, k=150)
#
# Threshold for terms > 15
# GO:		 3E-124 	(N=22231, n=2300, K=3483, k=859)
# Mutat:		 6E-267 	(N=22231, n=2300, K=733, k=585)
# N6AK:		 2E-08 	(N=22231, n=2300, K=100, k=35)
# PTMs:		 1E-39 	(N=22231, n=2300, K=6160, k=947)
# Seque:		 8E-01 	(N=22231, n=2300, K=22229, k=2300)
# Ubiq:		 2E-05 	(N=22231, n=2300, K=299, k=58)
# pSer:		 6E-05 	(N=22231, n=2300, K=2131, k=280)
# pThr:		 1E-04 	(N=22231, n=2300, K=385, k=67)
#
# Threshold for terms > 20
# GO:		 3E-92 	(N=22231, n=2300, K=2125, k=581)
# Mutat:		 2E-195 	(N=22231, n=2300, K=504, k=425)
# N6AK:		 7E-06 	(N=22231, n=2300, K=38, k=17)
# PTMs:		 2E-31 	(N=22231, n=2300, K=4459, k=711)
# Seque:		 8E-01 	(N=22231, n=2300, K=22229, k=2300)
# Ubiq:		 6E-04 	(N=22231, n=2300, K=148, k=31)
# pSer:		 9E-03 	(N=22231, n=2300, K=1434, k=179)
# pThr:		 5E-03 	(N=22231, n=2300, K=188, k=33)
#
# Threshold for terms > 25
# GO:		 1E-69 	(N=22231, n=2300, K=1377, k=406)
# Mutat:		 8E-167 	(N=22231, n=2300, K=402, k=356)
# N6AK:		 3E-04 	(N=22231, n=2300, K=20, k=10)
# PTMs:		 4E-27 	(N=22231, n=2300, K=3331, k=553)
# Seque:		 7E-01 	(N=22231, n=2300, K=22228, k=2300)
# Ubiq:		 2E-02 	(N=22231, n=2300, K=76, k=15)
# pSer:		 7E-03 	(N=22231, n=2300, K=996, k=130)
# pThr:		 1E-02 	(N=22231, n=2300, K=96, k=19)

# %%
# Out:
# 2273
